# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_curve, auc, mean_squared_error
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras import regularizers
from keras.utils import to_categorical
from sklearn.multiclass import OneVsOneClassifier
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier

# Load the dataset
dataset_path = '/content/augmented_balanced_data_new.csv'
df = pd.read_csv(dataset_path)

# Specify the number of components for PCA
num_components = 20  # Adjust the number of components as needed

# Initialize PCA
pca = PCA(n_components=num_components)

# Initialize lists to store performance metrics across folds after PCA
mse_scores_ensemble_pca = []
accuracy_scores_ensemble_pca = []

# 'class' column contains the target variable
X = df.drop('attack_method', axis=1)  # Features
y = df['attack_method']  # Target

# Preprocess the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Specify the number of splits for StratifiedKFold
num_splits = 5

# Initialize StratifiedKFold
stratified_kfold = StratifiedKFold(n_splits=num_splits, shuffle=True, random_state=42)

# Initialize lists to store performance metrics across folds
mse_scores_stacked_ndae = []
accuracy_scores_stacked_ndae = []
mse_scores_sparse_autoencoder = []
accuracy_scores_sparse_autoencoder = []
mse_scores_stacked_autoencoder = []
accuracy_scores_stacked_autoencoder = []
mse_scores_ensemble = []
accuracy_scores_ensemble = []

# Initialize lists to store ROC curve values
all_fpr = []
mean_tpr = []

# Initialize list to store epoch losses
all_epoch_losses = []

# Loop over the folds for cross-validation
for fold, (train_index, test_index) in enumerate(stratified_kfold.split(X_scaled, y), 1):
    print(f"\nFold {fold}")

    X_train_cv, X_test_cv = X_scaled[train_index], X_scaled[test_index]
    y_train_cv, y_test_cv = y.iloc[train_index], y.iloc[test_index]

    # Define and train Stacked NDAE model using Keras
    model = Sequential()

    # Input layer with 41 units
    model.add(Dense(units=41, input_dim=X_train_cv.shape[1], activation='relu'))

    # First NDAE layer with 3 encoder layers
    model.add(Dense(units=12, activation='relu'))
    model.add(Dense(units=24, activation='relu'))
    model.add(Dense(units=24, activation='relu'))

    # Second NDAE layer with 3 encoder layers
    model.add(Dense(units=12, activation='relu'))
    model.add(Dense(units=24, activation='relu'))
    model.add(Dense(units=24, activation='relu'))

    # Third NDAE layer with 3 encoder layers
    model.add(Dense(units=12, activation='relu'))
    model.add(Dense(units=24, activation='relu'))
    model.add(Dense(units=24, activation='relu'))

    # Output layer
    model.add(Dense(units=X_train_cv.shape[1], activation='sigmoid'))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

    # Initialize list to store epoch losses for this fold
    epoch_losses = []

    # Train the model and collect epoch losses
    for epoch in range(15):
        history = model.fit(X_train_cv, X_train_cv, epochs=1, batch_size=128, shuffle=True, validation_data=(X_test_cv, X_test_cv))
        epoch_losses.append(history.history['loss'][0])

    all_epoch_losses.append(epoch_losses)

    # Evaluate the model on the test set
    mse_stacked_ndae, accuracy_stacked_ndae = model.evaluate(X_test_cv, X_test_cv)
    print(f'Mean Squared Error (Stacked NDAE): {mse_stacked_ndae}')
    print(f'Accuracy (Stacked NDAE): {accuracy_stacked_ndae}')

    mse_scores_stacked_ndae.append(mse_stacked_ndae)
    accuracy_scores_stacked_ndae.append(accuracy_stacked_ndae)

    # To obtain the encoded representations
    encoded_train_stacked_ndae = model.predict(X_train_cv)
    encoded_test_stacked_ndae = model.predict(X_test_cv)


    # Define and train Sparse Autoencoder model using Keras
    sae_model = Sequential()

    # Input layer
    sae_model.add(Dense(units=X_train_cv.shape[1], input_dim=X_train_cv.shape[1], activation='relu'))

    # Sparse Hidden layer with L1 regularization for sparsity
    sae_model.add(Dense(units=20, activation='relu', activity_regularizer=regularizers.l1(10e-5)))

    # Fully connected output layer with softmax activation for classification
    sae_model.add(Dense(units=len(np.unique(y)), activation='sigmoid'))

    # Compile the model
    sae_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Convert labels to one-hot encoding
    y_train_cv_one_hot = to_categorical(y_train_cv)
    y_test_cv_one_hot = to_categorical(y_test_cv)

    # Train the model
    sae_model.fit(X_train_cv, y_train_cv_one_hot, epochs=15, batch_size=128, shuffle=True, validation_split=0.1)

    # Evaluate the model on the test set
    accuracy_sparse_autoencoder = sae_model.evaluate(X_test_cv, y_test_cv_one_hot)[1]
    print(f'Accuracy (Sparse Autoencoder): {accuracy_sparse_autoencoder}')

    accuracy_scores_sparse_autoencoder.append(accuracy_sparse_autoencoder)

    # Obtain encoded representations
    encoded_train_sparse = sae_model.predict(X_train_cv)
    encoded_test_sparse = sae_model.predict(X_test_cv)

    stacked_autoencoder = Sequential()

    # Input layer with 41 units
    stacked_autoencoder.add(Dense(units=41, input_dim=X_train_cv.shape[1], activation='relu'))

    # First NDAE layer with 3 encoder layers and 3 decoder layers
    stacked_autoencoder.add(Dense(units=12, activation='relu'))
    stacked_autoencoder.add(Dense(units=24, activation='relu'))
    stacked_autoencoder.add(Dense(units=24, activation='relu'))

    stacked_autoencoder.add(Dense(units=24, activation='relu'))
    stacked_autoencoder.add(Dense(units=24, activation='relu'))
    stacked_autoencoder.add(Dense(units=12, activation='relu'))

    # Second NDAE layer with 3 encoder layers and 3 decoder layers
    stacked_autoencoder.add(Dense(units=12, activation='relu'))
    stacked_autoencoder.add(Dense(units=24, activation='relu'))
    stacked_autoencoder.add(Dense(units=24, activation='relu'))

    stacked_autoencoder.add(Dense(units=24, activation='relu'))
    stacked_autoencoder.add(Dense(units=24, activation='relu'))
    stacked_autoencoder.add(Dense(units=12, activation='relu'))

    # Third NDAE layer with 3 encoder layers and 3 decoder layers
    stacked_autoencoder.add(Dense(units=12, activation='relu'))
    stacked_autoencoder.add(Dense(units=24, activation='relu'))
    stacked_autoencoder.add(Dense(units=24, activation='relu'))

    stacked_autoencoder.add(Dense(units=24, activation='relu'))
    stacked_autoencoder.add(Dense(units=24, activation='relu'))
    stacked_autoencoder.add(Dense(units=12, activation='relu'))



    # Compile the stacked autoencoder
    stacked_autoencoder.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Convert labels to one-hot encoding
    y_train_cv_one_hot = to_categorical(y_train_cv)
    y_test_cv_one_hot = to_categorical(y_test_cv)

    # Output layer of the stacked autoencoder
    stacked_autoencoder.add(Dense(units=len(np.unique(y)), activation='sigmoid'))

    # Train the stacked autoencoder
    for epoch in range(15):  # Adjust the number of epochs as needed
        history = stacked_autoencoder.fit(X_train_cv, y_train_cv_one_hot, epochs=1, batch_size=128, shuffle=True, validation_data=(X_test_cv, y_test_cv_one_hot))
        epoch_losses.append(history.history['loss'][0])

    all_epoch_losses.append(epoch_losses)

    # Evaluate the model on the test set
    accuracy_stacked_autoencoder = stacked_autoencoder.evaluate(X_test_cv, y_test_cv_one_hot)[1]
    print(f'Accuracy (Stacked Autoencoder): {accuracy_stacked_autoencoder}')

    accuracy_scores_stacked_autoencoder.append(accuracy_stacked_autoencoder)

    # Obtain encoded representations
    encoded_train_stacked = stacked_autoencoder.predict(X_train_cv)
    encoded_test_stacked = stacked_autoencoder.predict(X_test_cv)

    # Combine encoded representations from all autoencoders
    encoded_train_ensemble = np.concatenate((encoded_train_stacked_ndae, encoded_train_sparse, encoded_train_stacked), axis=1)
    encoded_test_ensemble = np.concatenate((encoded_test_stacked_ndae, encoded_test_sparse, encoded_test_stacked), axis=1)

    # Apply PCA to encoded representations
    encoded_train_pca = pca.fit_transform(encoded_train_ensemble)
    encoded_test_pca = pca.transform(encoded_test_ensemble)

     # Initialize k-NN classifier after PCA
    knn_pca = KNeighborsClassifier()

    # Fit the k-NN model after PCA
    knn_pca.fit(encoded_train_pca, y_train_cv)

    # Evaluate the k-NN model on the test set after PCA
    y_pred_pca = knn_pca.predict(encoded_test_pca)

    # Print classification report after PCA
    print(classification_report(y_test_cv, y_pred_pca))

    # Record performance metrics after PCA
    mse_pca, accuracy_pca = mean_squared_error(y_test_cv, y_pred_pca), knn_pca.score(encoded_test_pca, y_test_cv)
    print(f'Mean Squared Error (Ensemble + PCA): {mse_pca}')
    print(f'Accuracy (Ensemble + PCA): {accuracy_pca}')

    mse_scores_ensemble_pca.append(mse_pca)
    accuracy_scores_ensemble_pca.append(accuracy_pca)

# Print average performance metrics for the ensemble across folds after PCA
print("\nAverage Performance Across Folds (Ensemble + PCA):")
print(f"Mean Squared Error: {np.mean(mse_scores_ensemble_pca)}")
print(f'Accuracy: {np.mean(accuracy_scores_ensemble_pca)}')
# Out:
# Fold 1
# 504/504 [==============================] - 5s 6ms/step - loss: 0.9032 - accuracy: 0.0827 - val_loss: 0.7822 - val_accuracy: 0.0959
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8545 - accuracy: 0.0940 - val_loss: 0.7777 - val_accuracy: 0.0974
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8504 - accuracy: 0.0965 - val_loss: 0.7743 - val_accuracy: 0.1007
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8450 - accuracy: 0.1104 - val_loss: 0.7648 - val_accuracy: 0.1342
# 504/504 [==============================] - 3s 6ms/step - loss: 0.8373 - accuracy: 0.1344 - val_loss: 0.7634 - val_accuracy: 0.1367
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8346 - accuracy: 0.1332 - val_loss: 0.7594 - val_accuracy: 0.1339
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8330 - accuracy: 0.1319 - val_loss: 0.7582 - val_accuracy: 0.1383
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8322 - accuracy: 0.1325 - val_loss: 0.7574 - val_accuracy: 0.1315
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8313 - accuracy: 0.1325 - val_loss: 0.7567 - val_accuracy: 0.1390
# 504/504 [==============================] - 2s 5ms/step - loss: 0.8309 - accuracy: 0.1312 - val_loss: 0.7561 - val_accuracy: 0.1313
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8304 - accuracy: 0.1301 - val_loss: 0.7561 - val_accuracy: 0.1280
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8290 - accuracy: 0.1297 - val_loss: 0.7538 - val_accuracy: 0.1285
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8217 - accuracy: 0.1272 - val_loss: 0.7444 - val_accuracy: 0.1254
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8181 - accuracy: 0.1230 - val_loss: 0.7431 - val_accuracy: 0.1246
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8174 - accuracy: 0.1195 - val_loss: 0.7406 - val_accuracy: 0.1234
# 504/504 [==============================] - 1s 2ms/step - loss: 0.7406 - accuracy: 0.1235
# Mean Squared Error (Stacked NDAE): 0.740615725517273
# Accuracy (Stacked NDAE): 0.12351956218481064
# 2016/2016 [==============================] - 3s 2ms/step
# 504/504 [==============================] - 1s 1ms/step
# Epoch 1/15
# 454/454 [==============================] - 2s 4ms/step - loss: 0.4244 - accuracy: 0.8625 - val_loss: 0.1261 - val_accuracy: 0.9668
# Epoch 2/15
# 454/454 [==============================] - 2s 4ms/step - loss: 0.0921 - accuracy: 0.9749 - val_loss: 0.0634 - val_accuracy: 0.9805
# Epoch 3/15
# 454/454 [==============================] - 3s 8ms/step - loss: 0.0565 - accuracy: 0.9839 - val_loss: 0.0461 - val_accuracy: 0.9854
# Epoch 4/15
# 454/454 [==============================] - 4s 8ms/step - loss: 0.0431 - accuracy: 0.9875 - val_loss: 0.0357 - val_accuracy: 0.9904
# Epoch 5/15
# 454/454 [==============================] - 2s 5ms/step - loss: 0.0381 - accuracy: 0.9893 - val_loss: 0.0327 - val_accuracy: 0.9912
# Epoch 6/15
# 454/454 [==============================] - 2s 5ms/step - loss: 0.0326 - accuracy: 0.9909 - val_loss: 0.0294 - val_accuracy: 0.9927
# Epoch 7/15
# 454/454 [==============================] - 2s 5ms/step - loss: 0.0295 - accuracy: 0.9921 - val_loss: 0.0285 - val_accuracy: 0.9918
# Epoch 8/15
# 454/454 [==============================] - 2s 5ms/step - loss: 0.0264 - accuracy: 0.9930 - val_loss: 0.0261 - val_accuracy: 0.9938
# Epoch 9/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0245 - accuracy: 0.9939 - val_loss: 0.0232 - val_accuracy: 0.9949
# Epoch 10/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0225 - accuracy: 0.9945 - val_loss: 0.0222 - val_accuracy: 0.9949
# Epoch 11/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0209 - accuracy: 0.9946 - val_loss: 0.0227 - val_accuracy: 0.9940
# Epoch 12/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0190 - accuracy: 0.9955 - val_loss: 0.0218 - val_accuracy: 0.9949
# Epoch 13/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0175 - accuracy: 0.9960 - val_loss: 0.0198 - val_accuracy: 0.9957
# Epoch 14/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0171 - accuracy: 0.9961 - val_loss: 0.0185 - val_accuracy: 0.9957
# Epoch 15/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0155 - accuracy: 0.9965 - val_loss: 0.0177 - val_accuracy: 0.9963
# 504/504 [==============================] - 1s 1ms/step - loss: 0.0276 - accuracy: 0.9949
# Accuracy (Sparse Autoencoder): 0.9948533773422241
# 2016/2016 [==============================] - 3s 1ms/step
# 504/504 [==============================] - 1s 2ms/step
# 504/504 [==============================] - 6s 5ms/step - loss: 0.5159 - accuracy: 0.8219 - val_loss: 0.1850 - val_accuracy: 0.9555
# 504/504 [==============================] - 2s 5ms/step - loss: 0.1176 - accuracy: 0.9712 - val_loss: 0.0942 - val_accuracy: 0.9764
# 504/504 [==============================] - 3s 6ms/step - loss: 0.0781 - accuracy: 0.9794 - val_loss: 0.0731 - val_accuracy: 0.9795
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0660 - accuracy: 0.9820 - val_loss: 0.0698 - val_accuracy: 0.9826
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0556 - accuracy: 0.9845 - val_loss: 0.0568 - val_accuracy: 0.9852
# 504/504 [==============================] - 2s 4ms/step - loss: 0.0512 - accuracy: 0.9867 - val_loss: 0.0677 - val_accuracy: 0.9813
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0467 - accuracy: 0.9878 - val_loss: 0.0506 - val_accuracy: 0.9878
# 504/504 [==============================] - 3s 7ms/step - loss: 0.0434 - accuracy: 0.9888 - val_loss: 0.0486 - val_accuracy: 0.9872
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0384 - accuracy: 0.9899 - val_loss: 0.0689 - val_accuracy: 0.9843
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0428 - accuracy: 0.9893 - val_loss: 0.0576 - val_accuracy: 0.9844
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0377 - accuracy: 0.9899 - val_loss: 0.0521 - val_accuracy: 0.9864
# 504/504 [==============================] - 3s 7ms/step - loss: 0.0329 - accuracy: 0.9910 - val_loss: 0.0435 - val_accuracy: 0.9901
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0302 - accuracy: 0.9917 - val_loss: 0.0501 - val_accuracy: 0.9882
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0307 - accuracy: 0.9922 - val_loss: 0.0366 - val_accuracy: 0.9912
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0280 - accuracy: 0.9924 - val_loss: 0.0415 - val_accuracy: 0.9893
# 504/504 [==============================] - 1s 2ms/step - loss: 0.0415 - accuracy: 0.9893
# Accuracy (Stacked Autoencoder): 0.9892726540565491
# 2016/2016 [==============================] - 4s 2ms/step
# 504/504 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2016
#            1       1.00      1.00      1.00      8064
#            2       0.99      0.99      0.99      2015
#            3       0.99      0.99      0.99      2016
#            4       0.99      0.99      0.99      2016
#
#     accuracy                           0.99     16127
#    macro avg       0.99      0.99      0.99     16127
# weighted avg       0.99      0.99      0.99     16127
#
# Mean Squared Error (Ensemble + PCA): 0.019160414212190734
# Accuracy (Ensemble + PCA): 0.994171265579463
#
# Fold 2
# 504/504 [==============================] - 4s 4ms/step - loss: 0.9228 - accuracy: 0.2364 - val_loss: 0.7065 - val_accuracy: 0.3494
# 504/504 [==============================] - 2s 3ms/step - loss: 0.8659 - accuracy: 0.3470 - val_loss: 0.6991 - val_accuracy: 0.3572
# 504/504 [==============================] - 3s 5ms/step - loss: 0.8624 - accuracy: 0.3497 - val_loss: 0.6971 - val_accuracy: 0.3650
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8609 - accuracy: 0.3594 - val_loss: 0.6962 - val_accuracy: 0.3681
# 504/504 [==============================] - 2s 3ms/step - loss: 0.8598 - accuracy: 0.3662 - val_loss: 0.6956 - val_accuracy: 0.3669
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8594 - accuracy: 0.3635 - val_loss: 0.6949 - val_accuracy: 0.3696
# 504/504 [==============================] - 2s 5ms/step - loss: 0.8589 - accuracy: 0.3632 - val_loss: 0.6947 - val_accuracy: 0.3683
# 504/504 [==============================] - 2s 5ms/step - loss: 0.8587 - accuracy: 0.3639 - val_loss: 0.6945 - val_accuracy: 0.3694
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8585 - accuracy: 0.3651 - val_loss: 0.6942 - val_accuracy: 0.3683
# 504/504 [==============================] - 2s 3ms/step - loss: 0.8551 - accuracy: 0.3676 - val_loss: 0.6859 - val_accuracy: 0.3799
# 504/504 [==============================] - 2s 3ms/step - loss: 0.8482 - accuracy: 0.3727 - val_loss: 0.6830 - val_accuracy: 0.3833
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8408 - accuracy: 0.3771 - val_loss: 0.6745 - val_accuracy: 0.3819
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8382 - accuracy: 0.3739 - val_loss: 0.6734 - val_accuracy: 0.3876
# 504/504 [==============================] - 3s 6ms/step - loss: 0.8318 - accuracy: 0.3746 - val_loss: 0.6642 - val_accuracy: 0.2945
# 504/504 [==============================] - 2s 3ms/step - loss: 0.8284 - accuracy: 0.2731 - val_loss: 0.6641 - val_accuracy: 0.2847
# 504/504 [==============================] - 1s 2ms/step - loss: 0.6641 - accuracy: 0.2847
# Mean Squared Error (Stacked NDAE): 0.6640653610229492
# Accuracy (Stacked NDAE): 0.2846778631210327
# 2016/2016 [==============================] - 3s 2ms/step
# 504/504 [==============================] - 1s 2ms/step
# Epoch 1/15
# 454/454 [==============================] - 2s 3ms/step - loss: 0.3515 - accuracy: 0.9049 - val_loss: 0.1297 - val_accuracy: 0.9650
# Epoch 2/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.1002 - accuracy: 0.9726 - val_loss: 0.0700 - val_accuracy: 0.9800
# Epoch 3/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0605 - accuracy: 0.9826 - val_loss: 0.0480 - val_accuracy: 0.9871
# Epoch 4/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0454 - accuracy: 0.9877 - val_loss: 0.0397 - val_accuracy: 0.9893
# Epoch 5/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0368 - accuracy: 0.9898 - val_loss: 0.0339 - val_accuracy: 0.9909
# Epoch 6/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0329 - accuracy: 0.9913 - val_loss: 0.0315 - val_accuracy: 0.9922
# Epoch 7/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0294 - accuracy: 0.9926 - val_loss: 0.0308 - val_accuracy: 0.9924
# Epoch 8/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0265 - accuracy: 0.9930 - val_loss: 0.0294 - val_accuracy: 0.9938
# Epoch 9/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0247 - accuracy: 0.9940 - val_loss: 0.0270 - val_accuracy: 0.9936
# Epoch 10/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0230 - accuracy: 0.9941 - val_loss: 0.0262 - val_accuracy: 0.9941
# Epoch 11/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0206 - accuracy: 0.9948 - val_loss: 0.0239 - val_accuracy: 0.9955
# Epoch 12/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0191 - accuracy: 0.9954 - val_loss: 0.0233 - val_accuracy: 0.9957
# Epoch 13/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0177 - accuracy: 0.9956 - val_loss: 0.0234 - val_accuracy: 0.9952
# Epoch 14/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0162 - accuracy: 0.9963 - val_loss: 0.0224 - val_accuracy: 0.9963
# Epoch 15/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0160 - accuracy: 0.9964 - val_loss: 0.0212 - val_accuracy: 0.9958
# 504/504 [==============================] - 1s 1ms/step - loss: 0.0177 - accuracy: 0.9952
# Accuracy (Sparse Autoencoder): 0.9952253699302673
# 2016/2016 [==============================] - 3s 1ms/step
# 504/504 [==============================] - 1s 1ms/step
# 504/504 [==============================] - 6s 5ms/step - loss: 0.5812 - accuracy: 0.7675 - val_loss: 0.1749 - val_accuracy: 0.9557
# 504/504 [==============================] - 2s 4ms/step - loss: 0.1462 - accuracy: 0.9639 - val_loss: 0.1161 - val_accuracy: 0.9705
# 504/504 [==============================] - 3s 7ms/step - loss: 0.1148 - accuracy: 0.9707 - val_loss: 0.1169 - val_accuracy: 0.9660
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0862 - accuracy: 0.9755 - val_loss: 0.0638 - val_accuracy: 0.9801
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0725 - accuracy: 0.9790 - val_loss: 0.0618 - val_accuracy: 0.9823
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0623 - accuracy: 0.9822 - val_loss: 0.0543 - val_accuracy: 0.9852
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0578 - accuracy: 0.9842 - val_loss: 0.0501 - val_accuracy: 0.9869
# 504/504 [==============================] - 3s 6ms/step - loss: 0.0513 - accuracy: 0.9855 - val_loss: 0.0460 - val_accuracy: 0.9865
# 504/504 [==============================] - 2s 4ms/step - loss: 0.0494 - accuracy: 0.9863 - val_loss: 0.0674 - val_accuracy: 0.9827
# 504/504 [==============================] - 2s 4ms/step - loss: 0.0461 - accuracy: 0.9871 - val_loss: 0.0396 - val_accuracy: 0.9895
# 504/504 [==============================] - 2s 4ms/step - loss: 0.0436 - accuracy: 0.9876 - val_loss: 0.0412 - val_accuracy: 0.9887
# 504/504 [==============================] - 3s 6ms/step - loss: 0.0406 - accuracy: 0.9891 - val_loss: 0.0372 - val_accuracy: 0.9891
# 504/504 [==============================] - 2s 4ms/step - loss: 0.0358 - accuracy: 0.9902 - val_loss: 0.0438 - val_accuracy: 0.9883
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0396 - accuracy: 0.9896 - val_loss: 0.0445 - val_accuracy: 0.9864
# 504/504 [==============================] - 2s 4ms/step - loss: 0.0319 - accuracy: 0.9916 - val_loss: 0.0354 - val_accuracy: 0.9902
# 504/504 [==============================] - 1s 2ms/step - loss: 0.0354 - accuracy: 0.9902
# Accuracy (Stacked Autoencoder): 0.990202784538269
# 2016/2016 [==============================] - 5s 2ms/step
# 504/504 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2016
#            1       1.00      1.00      1.00      8064
#            2       0.99      0.98      0.99      2016
#            3       0.99      0.99      0.99      2015
#            4       0.99      0.99      0.99      2016
#
#     accuracy                           0.99     16127
#    macro avg       0.99      0.99      0.99     16127
# weighted avg       0.99      0.99      0.99     16127
#
# Mean Squared Error (Ensemble + PCA): 0.021082656414708252
# Accuracy (Ensemble + PCA): 0.9940472499534941
#
# Fold 3
# 504/504 [==============================] - 5s 5ms/step - loss: 0.8004 - accuracy: 0.0310 - val_loss: 1.1301 - val_accuracy: 0.0677
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7369 - accuracy: 0.0766 - val_loss: 1.1252 - val_accuracy: 0.0910
# 504/504 [==============================] - 2s 3ms/step - loss: 0.7335 - accuracy: 0.0886 - val_loss: 1.1229 - val_accuracy: 0.0808
# 504/504 [==============================] - 2s 3ms/step - loss: 0.7322 - accuracy: 0.0890 - val_loss: 1.1222 - val_accuracy: 0.0859
# 504/504 [==============================] - 2s 3ms/step - loss: 0.7286 - accuracy: 0.0893 - val_loss: 1.1123 - val_accuracy: 0.0916
# 504/504 [==============================] - 2s 5ms/step - loss: 0.7210 - accuracy: 0.0942 - val_loss: 1.1108 - val_accuracy: 0.1010
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7197 - accuracy: 0.0921 - val_loss: 1.1095 - val_accuracy: 0.1047
# 504/504 [==============================] - 2s 3ms/step - loss: 0.7181 - accuracy: 0.0945 - val_loss: 1.1079 - val_accuracy: 0.0894
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7167 - accuracy: 0.0902 - val_loss: 1.1046 - val_accuracy: 0.0933
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7123 - accuracy: 0.0920 - val_loss: 1.1021 - val_accuracy: 0.0895
# 504/504 [==============================] - 2s 5ms/step - loss: 0.7114 - accuracy: 0.0923 - val_loss: 1.1016 - val_accuracy: 0.0982
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7111 - accuracy: 0.0941 - val_loss: 1.1010 - val_accuracy: 0.0897
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7108 - accuracy: 0.0943 - val_loss: 1.1014 - val_accuracy: 0.0873
# 504/504 [==============================] - 2s 3ms/step - loss: 0.7106 - accuracy: 0.0937 - val_loss: 1.1006 - val_accuracy: 0.0915
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7102 - accuracy: 0.1002 - val_loss: 1.1004 - val_accuracy: 0.0953
# 504/504 [==============================] - 1s 2ms/step - loss: 1.1004 - accuracy: 0.0953
# Mean Squared Error (Stacked NDAE): 1.100428581237793
# Accuracy (Stacked NDAE): 0.09530600905418396
# 2016/2016 [==============================] - 4s 2ms/step
# 504/504 [==============================] - 1s 2ms/step
# Epoch 1/15
# 454/454 [==============================] - 2s 3ms/step - loss: 0.3796 - accuracy: 0.8798 - val_loss: 0.1140 - val_accuracy: 0.9702
# Epoch 2/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0812 - accuracy: 0.9762 - val_loss: 0.0624 - val_accuracy: 0.9826
# Epoch 3/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0506 - accuracy: 0.9858 - val_loss: 0.0447 - val_accuracy: 0.9895
# Epoch 4/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0399 - accuracy: 0.9892 - val_loss: 0.0377 - val_accuracy: 0.9896
# Epoch 5/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0339 - accuracy: 0.9907 - val_loss: 0.0322 - val_accuracy: 0.9930
# Epoch 6/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0304 - accuracy: 0.9920 - val_loss: 0.0295 - val_accuracy: 0.9929
# Epoch 7/15
# 454/454 [==============================] - 2s 4ms/step - loss: 0.0272 - accuracy: 0.9928 - val_loss: 0.0280 - val_accuracy: 0.9933
# Epoch 8/15
# 454/454 [==============================] - 2s 3ms/step - loss: 0.0251 - accuracy: 0.9934 - val_loss: 0.0260 - val_accuracy: 0.9946
# Epoch 9/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0225 - accuracy: 0.9940 - val_loss: 0.0288 - val_accuracy: 0.9926
# Epoch 10/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 0.0239 - val_accuracy: 0.9943
# Epoch 11/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0199 - accuracy: 0.9950 - val_loss: 0.0261 - val_accuracy: 0.9946
# Epoch 12/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0186 - accuracy: 0.9957 - val_loss: 0.0260 - val_accuracy: 0.9958
# Epoch 13/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0175 - accuracy: 0.9960 - val_loss: 0.0248 - val_accuracy: 0.9955
# Epoch 14/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0164 - accuracy: 0.9965 - val_loss: 0.0240 - val_accuracy: 0.9969
# Epoch 15/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0158 - accuracy: 0.9964 - val_loss: 0.0233 - val_accuracy: 0.9964
# 504/504 [==============================] - 1s 2ms/step - loss: 0.0769 - accuracy: 0.9950
# Accuracy (Sparse Autoencoder): 0.9950394034385681
# 2016/2016 [==============================] - 4s 2ms/step
# 504/504 [==============================] - 1s 1ms/step
# 504/504 [==============================] - 6s 6ms/step - loss: 0.6349 - accuracy: 0.7486 - val_loss: 0.2077 - val_accuracy: 0.9518
# 504/504 [==============================] - 3s 5ms/step - loss: 0.1433 - accuracy: 0.9632 - val_loss: 0.1229 - val_accuracy: 0.9683
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0987 - accuracy: 0.9735 - val_loss: 0.1124 - val_accuracy: 0.9803
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0759 - accuracy: 0.9792 - val_loss: 0.0912 - val_accuracy: 0.9835
# 504/504 [==============================] - 4s 7ms/step - loss: 0.0647 - accuracy: 0.9820 - val_loss: 0.0847 - val_accuracy: 0.9828
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0530 - accuracy: 0.9846 - val_loss: 0.0692 - val_accuracy: 0.9860
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0456 - accuracy: 0.9861 - val_loss: 0.0599 - val_accuracy: 0.9868
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0392 - accuracy: 0.9888 - val_loss: 0.0516 - val_accuracy: 0.9891
# 504/504 [==============================] - 3s 7ms/step - loss: 0.0361 - accuracy: 0.9904 - val_loss: 0.0588 - val_accuracy: 0.9886
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0329 - accuracy: 0.9910 - val_loss: 0.0357 - val_accuracy: 0.9918
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0303 - accuracy: 0.9919 - val_loss: 0.0531 - val_accuracy: 0.9909
# 504/504 [==============================] - 3s 6ms/step - loss: 0.0286 - accuracy: 0.9924 - val_loss: 0.0338 - val_accuracy: 0.9931
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0282 - accuracy: 0.9926 - val_loss: 0.0335 - val_accuracy: 0.9922
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0237 - accuracy: 0.9939 - val_loss: 0.0231 - val_accuracy: 0.9941
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0260 - accuracy: 0.9934 - val_loss: 0.0242 - val_accuracy: 0.9940
# 504/504 [==============================] - 1s 2ms/step - loss: 0.0242 - accuracy: 0.9940
# Accuracy (Stacked Autoencoder): 0.994047224521637
# 2016/2016 [==============================] - 4s 2ms/step
# 504/504 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2016
#            1       1.00      1.00      1.00      8063
#            2       0.99      0.99      0.99      2016
#            3       0.99      0.99      0.99      2016
#            4       0.99      0.99      0.99      2016
#
#     accuracy                           1.00     16127
#    macro avg       0.99      0.99      0.99     16127
# weighted avg       1.00      1.00      1.00     16127
#
# Mean Squared Error (Ensemble + PCA): 0.016990140757735476
# Accuracy (Ensemble + PCA): 0.995163390587214
#
# Fold 4
# 504/504 [==============================] - 4s 4ms/step - loss: 0.9423 - accuracy: 0.0642 - val_loss: 0.7680 - val_accuracy: 0.0915
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8947 - accuracy: 0.0985 - val_loss: 0.7622 - val_accuracy: 0.1006
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8910 - accuracy: 0.1029 - val_loss: 0.7598 - val_accuracy: 0.1001
# 504/504 [==============================] - 3s 5ms/step - loss: 0.8881 - accuracy: 0.1046 - val_loss: 0.7551 - val_accuracy: 0.1050
# 504/504 [==============================] - 2s 5ms/step - loss: 0.8816 - accuracy: 0.1090 - val_loss: 0.7497 - val_accuracy: 0.1003
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8776 - accuracy: 0.1087 - val_loss: 0.7439 - val_accuracy: 0.1041
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8712 - accuracy: 0.1116 - val_loss: 0.7385 - val_accuracy: 0.1116
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8674 - accuracy: 0.1200 - val_loss: 0.7341 - val_accuracy: 0.1191
# 504/504 [==============================] - 3s 6ms/step - loss: 0.8630 - accuracy: 0.1389 - val_loss: 0.7316 - val_accuracy: 0.1530
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8593 - accuracy: 0.1540 - val_loss: 0.7260 - val_accuracy: 0.1559
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8560 - accuracy: 0.1574 - val_loss: 0.7260 - val_accuracy: 0.1614
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8545 - accuracy: 0.1583 - val_loss: 0.7216 - val_accuracy: 0.1468
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8508 - accuracy: 0.1610 - val_loss: 0.7202 - val_accuracy: 0.1523
# 504/504 [==============================] - 3s 6ms/step - loss: 0.8502 - accuracy: 0.1587 - val_loss: 0.7199 - val_accuracy: 0.1565
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8498 - accuracy: 0.1594 - val_loss: 0.7193 - val_accuracy: 0.1601
# 504/504 [==============================] - 1s 2ms/step - loss: 0.7193 - accuracy: 0.1601
# Mean Squared Error (Stacked NDAE): 0.7192589640617371
# Accuracy (Stacked NDAE): 0.1601041704416275
# 2016/2016 [==============================] - 3s 2ms/step
# 504/504 [==============================] - 1s 2ms/step
# Epoch 1/15
# 454/454 [==============================] - 3s 4ms/step - loss: 0.3719 - accuracy: 0.8870 - val_loss: 0.1238 - val_accuracy: 0.9668
# Epoch 2/15
# 454/454 [==============================] - 2s 4ms/step - loss: 0.0906 - accuracy: 0.9762 - val_loss: 0.0593 - val_accuracy: 0.9822
# Epoch 3/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0548 - accuracy: 0.9853 - val_loss: 0.0440 - val_accuracy: 0.9856
# Epoch 4/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0413 - accuracy: 0.9882 - val_loss: 0.0353 - val_accuracy: 0.9891
# Epoch 5/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0341 - accuracy: 0.9903 - val_loss: 0.0293 - val_accuracy: 0.9918
# Epoch 6/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0297 - accuracy: 0.9920 - val_loss: 0.0280 - val_accuracy: 0.9919
# Epoch 7/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0274 - accuracy: 0.9930 - val_loss: 0.0251 - val_accuracy: 0.9936
# Epoch 8/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0241 - accuracy: 0.9938 - val_loss: 0.0228 - val_accuracy: 0.9932
# Epoch 9/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0228 - accuracy: 0.9945 - val_loss: 0.0212 - val_accuracy: 0.9955
# Epoch 10/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0208 - accuracy: 0.9948 - val_loss: 0.0209 - val_accuracy: 0.9946
# Epoch 11/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0191 - accuracy: 0.9955 - val_loss: 0.0199 - val_accuracy: 0.9949
# Epoch 12/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0177 - accuracy: 0.9960 - val_loss: 0.0195 - val_accuracy: 0.9952
# Epoch 13/15
# 454/454 [==============================] - 2s 4ms/step - loss: 0.0172 - accuracy: 0.9961 - val_loss: 0.0193 - val_accuracy: 0.9957
# Epoch 14/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0165 - accuracy: 0.9961 - val_loss: 0.0195 - val_accuracy: 0.9949
# Epoch 15/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0155 - accuracy: 0.9966 - val_loss: 0.0190 - val_accuracy: 0.9953
# 504/504 [==============================] - 1s 2ms/step - loss: 0.0282 - accuracy: 0.9934
# Accuracy (Sparse Autoencoder): 0.9933651685714722
# 2016/2016 [==============================] - 3s 1ms/step
# 504/504 [==============================] - 1s 1ms/step
# 504/504 [==============================] - 7s 5ms/step - loss: 0.6691 - accuracy: 0.7265 - val_loss: 0.2121 - val_accuracy: 0.9479
# 504/504 [==============================] - 3s 5ms/step - loss: 0.1445 - accuracy: 0.9648 - val_loss: 0.1189 - val_accuracy: 0.9678
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0991 - accuracy: 0.9722 - val_loss: 0.0901 - val_accuracy: 0.9729
# 504/504 [==============================] - 3s 7ms/step - loss: 0.0801 - accuracy: 0.9764 - val_loss: 0.0792 - val_accuracy: 0.9789
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0639 - accuracy: 0.9817 - val_loss: 0.0708 - val_accuracy: 0.9800
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0613 - accuracy: 0.9823 - val_loss: 0.0672 - val_accuracy: 0.9811
# 504/504 [==============================] - 3s 6ms/step - loss: 0.0587 - accuracy: 0.9837 - val_loss: 0.0626 - val_accuracy: 0.9833
# 504/504 [==============================] - 3s 6ms/step - loss: 0.0634 - accuracy: 0.9819 - val_loss: 0.0586 - val_accuracy: 0.9828
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0509 - accuracy: 0.9852 - val_loss: 0.0841 - val_accuracy: 0.9748
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0652 - accuracy: 0.9821 - val_loss: 0.0723 - val_accuracy: 0.9805
# 504/504 [==============================] - 4s 7ms/step - loss: 0.0535 - accuracy: 0.9854 - val_loss: 0.0554 - val_accuracy: 0.9854
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0460 - accuracy: 0.9871 - val_loss: 0.0584 - val_accuracy: 0.9836
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0483 - accuracy: 0.9870 - val_loss: 0.0458 - val_accuracy: 0.9895
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0439 - accuracy: 0.9889 - val_loss: 0.0472 - val_accuracy: 0.9892
# 504/504 [==============================] - 3s 6ms/step - loss: 0.0346 - accuracy: 0.9909 - val_loss: 0.0467 - val_accuracy: 0.9884
# 504/504 [==============================] - 1s 2ms/step - loss: 0.0467 - accuracy: 0.9884
# Accuracy (Stacked Autoencoder): 0.9884045124053955
# 2016/2016 [==============================] - 4s 2ms/step
# 504/504 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2016
#            1       1.00      1.00      1.00      8063
#            2       0.98      0.98      0.98      2016
#            3       0.99      0.98      0.99      2016
#            4       0.98      0.99      0.99      2016
#
#     accuracy                           0.99     16127
#    macro avg       0.99      0.99      0.99     16127
# weighted avg       0.99      0.99      0.99     16127
#
# Mean Squared Error (Ensemble + PCA): 0.020896632975754944
# Accuracy (Ensemble + PCA): 0.9926210702548521
#
# Fold 5
# 504/504 [==============================] - 4s 4ms/step - loss: 0.9008 - accuracy: 0.2073 - val_loss: 0.8298 - val_accuracy: 0.2644
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8462 - accuracy: 0.2672 - val_loss: 0.8245 - val_accuracy: 0.2795
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8388 - accuracy: 0.2981 - val_loss: 0.8149 - val_accuracy: 0.3296
# 504/504 [==============================] - 3s 6ms/step - loss: 0.8283 - accuracy: 0.3088 - val_loss: 0.8031 - val_accuracy: 0.3357
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8128 - accuracy: 0.3227 - val_loss: 0.7911 - val_accuracy: 0.3130
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8073 - accuracy: 0.3268 - val_loss: 0.7853 - val_accuracy: 0.3355
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8027 - accuracy: 0.3463 - val_loss: 0.7824 - val_accuracy: 0.3294
# 504/504 [==============================] - 2s 4ms/step - loss: 0.8008 - accuracy: 0.3475 - val_loss: 0.7798 - val_accuracy: 0.3544
# 504/504 [==============================] - 3s 6ms/step - loss: 0.7981 - accuracy: 0.3628 - val_loss: 0.7796 - val_accuracy: 0.3809
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7970 - accuracy: 0.3666 - val_loss: 0.7778 - val_accuracy: 0.3661
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7964 - accuracy: 0.3661 - val_loss: 0.7762 - val_accuracy: 0.3785
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7923 - accuracy: 0.3579 - val_loss: 0.7722 - val_accuracy: 0.3798
# 504/504 [==============================] - 3s 6ms/step - loss: 0.7908 - accuracy: 0.3672 - val_loss: 0.7713 - val_accuracy: 0.3427
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7898 - accuracy: 0.3867 - val_loss: 0.7705 - val_accuracy: 0.4113
# 504/504 [==============================] - 2s 4ms/step - loss: 0.7893 - accuracy: 0.3976 - val_loss: 0.7699 - val_accuracy: 0.4093
# 504/504 [==============================] - 1s 2ms/step - loss: 0.7699 - accuracy: 0.4093
# Mean Squared Error (Stacked NDAE): 0.7698692083358765
# Accuracy (Stacked NDAE): 0.40927693247795105
# 2016/2016 [==============================] - 3s 2ms/step
# 504/504 [==============================] - 1s 2ms/step
# Epoch 1/15
# 454/454 [==============================] - 2s 3ms/step - loss: 0.3610 - accuracy: 0.8994 - val_loss: 0.1216 - val_accuracy: 0.9647
# Epoch 2/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0872 - accuracy: 0.9759 - val_loss: 0.0599 - val_accuracy: 0.9843
# Epoch 3/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0516 - accuracy: 0.9861 - val_loss: 0.0435 - val_accuracy: 0.9896
# Epoch 4/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0398 - accuracy: 0.9897 - val_loss: 0.0358 - val_accuracy: 0.9910
# Epoch 5/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0336 - accuracy: 0.9912 - val_loss: 0.0318 - val_accuracy: 0.9935
# Epoch 6/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0295 - accuracy: 0.9921 - val_loss: 0.0288 - val_accuracy: 0.9947
# Epoch 7/15
# 454/454 [==============================] - 1s 3ms/step - loss: 0.0269 - accuracy: 0.9930 - val_loss: 0.0271 - val_accuracy: 0.9944
# Epoch 8/15
# 454/454 [==============================] - 2s 4ms/step - loss: 0.0251 - accuracy: 0.9937 - val_loss: 0.0256 - val_accuracy: 0.9947
# Epoch 9/15
# 454/454 [==============================] - 2s 4ms/step - loss: 0.0224 - accuracy: 0.9942 - val_loss: 0.0249 - val_accuracy: 0.9953
# Epoch 10/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0207 - accuracy: 0.9951 - val_loss: 0.0223 - val_accuracy: 0.9949
# Epoch 11/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0196 - accuracy: 0.9954 - val_loss: 0.0222 - val_accuracy: 0.9949
# Epoch 12/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0186 - accuracy: 0.9955 - val_loss: 0.0208 - val_accuracy: 0.9952
# Epoch 13/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0168 - accuracy: 0.9959 - val_loss: 0.0196 - val_accuracy: 0.9960
# Epoch 14/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0162 - accuracy: 0.9965 - val_loss: 0.0197 - val_accuracy: 0.9953
# Epoch 15/15
# 454/454 [==============================] - 1s 2ms/step - loss: 0.0149 - accuracy: 0.9968 - val_loss: 0.0183 - val_accuracy: 0.9966
# 504/504 [==============================] - 1s 2ms/step - loss: 0.0228 - accuracy: 0.9944
# Accuracy (Sparse Autoencoder): 0.9943569302558899
# 2016/2016 [==============================] - 3s 1ms/step
# 504/504 [==============================] - 1s 2ms/step
# 504/504 [==============================] - 6s 5ms/step - loss: 0.6495 - accuracy: 0.7172 - val_loss: 0.2109 - val_accuracy: 0.9477
# 504/504 [==============================] - 2s 5ms/step - loss: 0.1235 - accuracy: 0.9673 - val_loss: 0.0976 - val_accuracy: 0.9735
# 504/504 [==============================] - 4s 7ms/step - loss: 0.0760 - accuracy: 0.9781 - val_loss: 0.0649 - val_accuracy: 0.9799
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0604 - accuracy: 0.9826 - val_loss: 0.0677 - val_accuracy: 0.9808
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0534 - accuracy: 0.9847 - val_loss: 0.0560 - val_accuracy: 0.9854
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0488 - accuracy: 0.9866 - val_loss: 0.0581 - val_accuracy: 0.9865
# 504/504 [==============================] - 3s 6ms/step - loss: 0.0460 - accuracy: 0.9875 - val_loss: 0.0609 - val_accuracy: 0.9822
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0406 - accuracy: 0.9886 - val_loss: 0.0503 - val_accuracy: 0.9873
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0395 - accuracy: 0.9888 - val_loss: 0.0547 - val_accuracy: 0.9862
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0398 - accuracy: 0.9889 - val_loss: 0.0663 - val_accuracy: 0.9839
# 504/504 [==============================] - 3s 7ms/step - loss: 0.0629 - accuracy: 0.9811 - val_loss: 0.0659 - val_accuracy: 0.9810
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0446 - accuracy: 0.9874 - val_loss: 0.0512 - val_accuracy: 0.9854
# 504/504 [==============================] - 2s 5ms/step - loss: 0.0368 - accuracy: 0.9900 - val_loss: 0.0444 - val_accuracy: 0.9885
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0313 - accuracy: 0.9916 - val_loss: 0.0460 - val_accuracy: 0.9896
# 504/504 [==============================] - 3s 5ms/step - loss: 0.0297 - accuracy: 0.9925 - val_loss: 0.0447 - val_accuracy: 0.9882
# 504/504 [==============================] - 2s 3ms/step - loss: 0.0447 - accuracy: 0.9882
# Accuracy (Stacked Autoencoder): 0.9882177710533142
# 2016/2016 [==============================] - 4s 2ms/step
# 504/504 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2015
#            1       1.00      1.00      1.00      8064
#            2       0.99      0.98      0.98      2016
#            3       0.99      0.98      0.99      2016
#            4       0.99      0.99      0.99      2015
#
#     accuracy                           0.99     16126
#    macro avg       0.99      0.99      0.99     16126
# weighted avg       0.99      0.99      0.99     16126
#
# Mean Squared Error (Ensemble + PCA): 0.022014138658067717
# Accuracy (Ensemble + PCA): 0.9927446359915664
#
# Average Performance Across Folds (Ensemble + PCA):
# Mean Squared Error: 0.020028796603691425
# Accuracy: 0.9937495224733178

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Load test set
test_dataset_path = '/content/encoded_best_test_data.csv'
df_test = pd.read_csv(test_dataset_path)

# Extract features and target from the testing dataset
X_test = df_test.drop('attack_method', axis=1)
y_test = df_test['attack_method']

# Preprocess the testing data using the same scaler used for training data
X_test_scaled = scaler.transform(X_test)

# Obtain encoded representations for the testing data using the trained autoencoders
encoded_test_stacked_ndae = model.predict(X_test_scaled)
encoded_test_sparse = sae_model.predict(X_test_scaled)
encoded_test_stacked = stacked_autoencoder.predict(X_test_scaled)

# Combine encoded representations from all autoencoders
encoded_test_ensemble = np.concatenate((encoded_test_stacked_ndae, encoded_test_sparse, encoded_test_stacked), axis=1)

# Apply PCA to encoded representations for testing data
encoded_test_pca = pca.transform(encoded_test_ensemble)

# Use the trained SVM model after PCA to make predictions on the testing data
y_pred_test_pca = knn_pca.predict(encoded_test_pca)

# Calculate accuracy, precision, recall, and F1 score
accuracy_test_pca = accuracy_score(y_test, y_pred_test_pca)
precision_test_pca = precision_score(y_test, y_pred_test_pca, average='weighted')
recall_test_pca = recall_score(y_test, y_pred_test_pca, average='weighted')
f1_test_pca = f1_score(y_test, y_pred_test_pca, average='weighted')

# Display accuracy, precision, recall, and F1 score
print(f'Accuracy (Testing): {accuracy_test_pca}')
print(f'Precision (Testing): {precision_test_pca}')
print(f'Recall (Testing): {recall_test_pca}')
print(f'F1 Score (Testing): {f1_test_pca}')

# Convert labels to binary format for multi-class ROC curve
y_test_bin = label_binarize(y_test, classes=list(set(y_test)))

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_test_pca)

# Plot confusion matrix and bar graph
plt.figure(figsize=(15, 6))
# Out:
# 929/929 [==============================] - 1s 1ms/step
# 929/929 [==============================] - 1s 1ms/step
# 929/929 [==============================] - 2s 2ms/step
# Accuracy (Testing): 0.9587272381194086
# Precision (Testing): 0.9637402958176418
# Recall (Testing): 0.9588364280456726
# F1 Score (Testing): 0.9972578715270695

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import numpy as np

# Mapping numerical labels to attack categories
label_mapping = {0: 'ddos', 1: 'normal', 2: 'probe', 3: 'r2l', 4: 'u2r', 5: 'null'}

# Assuming 'labels' is the array of unique labels in the dataset
unique_labels = np.unique(y_test)

# Calculate metrics for each attack category
metrics_per_label = {}
accuracy_per_label = []

for label in unique_labels:
    if label == 5:  # Skip the "null" label
        continue

    indices = y_test == label
    true_labels = y_test[indices]
    predicted_labels = y_pred_test_pca[indices]

    accuracy = accuracy_score(true_labels, predicted_labels)
    precision = precision_score(true_labels, predicted_labels, average='weighted', zero_division=1)
    recall = recall_score(true_labels, predicted_labels, average='weighted', zero_division=1)
    f1 = f1_score(true_labels, predicted_labels, average='weighted', zero_division=1)

    attack_category = label_mapping.get(label, f'Unknown Label {label}')
    metrics_per_label[attack_category] = {
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    }
    accuracy_per_label.append(accuracy)
    print(f"\nMetrics for {attack_category.capitalize()}:")
    print(f"Accuracy: {accuracy * 100:.2f}%")

# Plot bar graph for accuracy of each label
plt.figure(figsize=(10, 6))
sns.barplot(x=list(metrics_per_label.keys()), y=accuracy_per_label, palette="viridis")
plt.xlabel('Attack Category')
plt.ylabel('Accuracy')
plt.title('Accuracy for Each Attack Category')
plt.xticks(rotation=45, ha='right')
plt.show()

# Filter out "null" label from overall metrics
filtered_indices = y_test != 5
overall_report = classification_report(y_test[filtered_indices], y_pred_test_pca[filtered_indices],
                                       labels=[0, 1, 2, 3, 4], target_names=label_mapping.values(), digits=4)
print("\nOverall Metrics:")
print(overall_report)

# Calculate confusion matrix for the overall dataset
conf_matrix_overall = confusion_matrix(y_test, y_pred_test_pca)

# Plot confusion matrix
plt.subplot(1, 2, 2)
sns.heatmap(conf_matrix_overall, annot=True, fmt="d", cmap="Blues", xticklabels=set(y_test), yticklabels=set(y_test))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')

plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# Metrics for Ddos:
# Accuracy: 99.80%
#
# Metrics for Normal:
# Accuracy: 99.82%
#
# Metrics for Probe:
# Accuracy: 98.63%
#
# Metrics for R2l:
# Accuracy: 98.55%
#
# Metrics for U2r:
# Accuracy: 70.74%
# <ipython-input-7-d198d52816a8>:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(metrics_per_label.keys()), y=accuracy_per_label, palette="viridis")
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:2326: UserWarning: labels size, 5, does not match size of target_names, 6
#   warnings.warn(
# Overall Metrics:
#               precision    recall  f1-score   support
#
#         ddos     0.9934    0.9980    0.9957      3940
#       normal     0.9966    0.9982    0.9974     15762
#        probe     0.9393    0.9863    0.9622      3940
#          r2l     0.8085    0.9855    0.8883      3940
#          u2r     0.9824    0.7074    0.8225      3940
#
#     accuracy                         0.9587     31522
#    macro avg     0.9440    0.9351    0.9332     31522
# weighted avg     0.9637    0.9587    0.9573     31522
